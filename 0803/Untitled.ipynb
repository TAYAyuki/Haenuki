# %%
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
from pandas import Series, DataFrame
import csv
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Lasso
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import cross_validate
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
# %matplotlib inline

# %%
df = pd.read_csv("./dataset/input/train.csv")

# %%
train, test = train_test_split(df, test_size = 0.3)

# %%
train_data = pd.get_dummies(train)
test_data = pd.get_dummies(test)
print(train_data.shape[1])
# Out:
# 51

# %%
train_X = train.drop('y', axis=1)
train_y = train['y']
test_X = test.drop('y', axis=1)
test_y = test['y']
print(train_X.shape[1])
# Out:
# 17

# %%
train_X.head()
# Out:
#           id  age            job   marital  education default  balance  \
# 14779  14779   31       services  divorced  secondary      no    83609
# 19627  19627   34    blue-collar   married  secondary      no    49269
# 1767    1767   60     management   married   tertiary      no    57075
# 4281    4281   30  self-employed    single   tertiary      no    64220
# 5808    5808   30    blue-collar   married  secondary      no    68820
#
#       housing loan   contact  day month  duration  campaign  pdays  previous  \
# 14779     yes  yes   unknown   16   may       259         2    476         0
# 19627     yes   no   unknown   16   may       658         2    560         0
# 1767       no   no  cellular   30   jul       161         1    758         2
# 4281      yes   no   unknown   26   may       121         1    672         0
# 5808      yes   no  cellular    4   aug       177         1    485         0
#
#       poutcome season
# 14779  unknown    NaN
# 19627  unknown    NaN
# ...

# %% [raw]
# for i in range(0,len(train_X)):
#     if train_X.iloc[i,'day']>=1 and train_X.iloc[i,'day']<=10:
#         train_X.loc[i,'season']='上旬'
#     elif train_X.iloc[i,'day']>10 and train_X.iloc[i,'day']<=20:
#         train_X.loc[i,'season']='中旬'
#     else:
#         train_X.loc[i,'season']='下旬'
#
# for i in range(0,len(test_X)):
#     if test_X.iloc[i,'day']>=1 and test_X.iloc[i,'day']<=10:
#         test_X.loc[i,'season']='上旬'
#     elif test_X.iloc[i,'day']>10 and test_X.iloc[i,'day']<=20:
#         test_X.loc[i,'season']='中旬'
#     else:
#         test_X.loc[i,'season']='下旬'

# %%
for data in train_X.iterrows():
    if data[1]['day'] >= 1 and data[1]['day'] <= 10:
        train_X.loc[data[0], 'season'] = '上旬'
    elif data[1]['day'] >= 10 and data[1]['day'] <= 20:
        train_X.loc[data[0], 'season'] = '中旬'
    else:
        train_X.loc[data[0], 'season'] = '下旬'

# %%
train_X.head()
# Out:
#           id  age            job   marital  education default  balance  \
# 14779  14779   31       services  divorced  secondary      no    83609
# 19627  19627   34    blue-collar   married  secondary      no    49269
# 1767    1767   60     management   married   tertiary      no    57075
# 4281    4281   30  self-employed    single   tertiary      no    64220
# 5808    5808   30    blue-collar   married  secondary      no    68820
#
#       housing loan   contact  day month  duration  campaign  pdays  previous  \
# 14779     yes  yes   unknown   16   may       259         2    476         0
# 19627     yes   no   unknown   16   may       658         2    560         0
# 1767       no   no  cellular   30   jul       161         1    758         2
# 4281      yes   no   unknown   26   may       121         1    672         0
# 5808      yes   no  cellular    4   aug       177         1    485         0
#
#       poutcome season
# 14779  unknown     中旬
# 19627  unknown     中旬
# ...

# %%
for data in test_X.iterrows():
    if data[1]['day'] >= 1 and data[1]['day'] <= 10:
        test_X.loc[data[0], 'season'] = '上旬'
    elif data[1]['day'] >= 10 and data[1]['day'] <= 20:
        test_X.loc[data[0], 'season'] = '中旬'
    else:
        test_X.loc[data[0], 'season'] = '下旬'

# %%
test_X.head()
# Out:
#           id  age           job   marital  education default  balance housing  \
# 26773  26773   35    technician   married  secondary      no    11161     yes
# 23421  23421   49  entrepreneur   married   tertiary      no    88803      no
# 18743  18743   30      services   married  secondary      no    24655     yes
# 17260  17260   35    technician   married  secondary      no    91175     yes
# 20813  20813   31        admin.  divorced  secondary      no    22707      no
#
#       loan   contact  day month  duration  campaign  pdays  previous poutcome  \
# 26773   no  cellular   27   may       345         1    645         0  unknown
# 23421   no   unknown    3   jun       158         2     61         0  unknown
# 18743   no  cellular   27   may       121         4    292         0  failure
# 17260  yes   unknown   16   may       345         1    422         0  unknown
# 20813  yes  cellular    7   jul       189         4    207         0  unknown
#
#       season
# 26773     下旬
# ...

# %%
#○月上旬という変数(allseason)を作る
train_X['allseason'] =train_X['month']+train_X['season'] 
test_X['allseason'] =test_X['month']+test_X['season']

# %%
#○月□旬の接触人数が400人以上か以下かで場合分け
for data in train_X.iterrows():
    if train_X['allseason'].value_counts()[train_X.loc[i,'allseason']]<=400:
        train_X.loc[data[0],'allseason'] = 1
    else:
        train_X.loc[data[0],'allseason'] = 0
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-26-73bc67d82e9d> in <module>
#       7
#       8 for data in train_X.iterrows():
# ...

# %%
for data in train_X.iterrows():
    if test_X['allseason'].value_counts()[test_X.loc[i,'allseason']]<=400:
        test_X.loc[data[0],'allseason'] = 1
    else:
        test_X.loc[data[0],'allseason'] = 0

# %%
#学生('student')かその他('not-student')でマッピング
for i in range(0,len(trainX)):
    if trainX.loc[i,'job']=='student':
        trainX.loc[i,'job']=='student'
    else:
        trainX.loc[i,'job'] = 'not-student'

for i in range(0,len(testX)):
    if testX.loc[i,'job']=='student':
        testX.loc[i,'job']=='student'
    else:
        testX.loc[i,'job'] = 'not-student'
